# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
y = [1,3,5,6,7,8,10,11]
x = [1,2,1,2,2,2,1,1]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, '.')

# %%
plt.scatter(x,y)

# %%
plt.plot(y)

# %%
y = np.random.randint(300, size=200)
y
# Out:
# array([ 80, 134, 200, 292,  56, 177,  60, 277,   4, 274, 211,  89,  60,
#        180,  13, 205, 157,  24, 139,  31,  18, 202, 295,  84, 248, 231,
#        168, 161,   1, 139,  42, 283, 132, 111, 103,  69, 176, 178, 173,
#        179, 159,  56, 180, 245, 158, 271, 217, 163, 278, 264, 199, 211,
#        201, 290, 171, 161, 195,  18, 127, 272, 198, 200, 196, 184, 236,
#         10,  63, 267,  96, 220, 197,  47, 182, 298, 203, 201,  84, 286,
#        160,  23,  16, 239,  73, 211,  10, 186, 239,  98,  40, 151, 183,
#         73,  16, 196, 274,   6, 234,  66, 102,  99, 255,  95,  20,  44,
#        223,   9, 134,  99, 259, 236, 286, 209,  59,   0,  40,  44, 294,
#         50,  37, 241, 142, 142, 120,  87, 263, 287, 111, 288,  84, 134,
#         33,  18, 277, 134, 259, 189,  23,  17, 195,  70, 292, 133, 151,
#        112,  62, 215, 249, 199, 259, 197, 100, 166, 258, 256,  14, 101,
#        239, 112, 208, 238, 131, 226,  97, 198, 129, 153,  33, 171,   3,
# ...

# %%
plt.hist(y, bins=30)
plt.show()
plt.hist(y, bins=10)
# Out:
# (array([23., 17., 17., 19., 15., 21., 30., 17., 19., 22.]),
#  array([  0. ,  29.8,  59.6,  89.4, 119.2, 149. , 178.8, 208.6, 238.4,
#         268.2, 298. ]),
#  <a list of 10 Patch objects>)
